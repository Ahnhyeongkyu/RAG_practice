# %%
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()
# Out:
# True

# %%
# !pip install langchain_experimental
# Out:
# Collecting langchain_experimental
#   Downloading langchain_experimental-0.0.62-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.6 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain_experimental) (0.2.9)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.10 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain_experimental) (0.2.22)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.9 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.2.10)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.1.90)
# Requirement already satisfied: numpy<2,>=1 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-community<0.3.0,>=0.2.6->langchain_experimental) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_experimental) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain-core<0.3.0,>=0.2.10->langchain_experimental) (2.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain_experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langchain<0.3.0,>=0.2.9->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (0.2.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.10->langchain_experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.10->langchain_experimental) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.10->langchain_experimental) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\userk\miniforge3\envs\rag\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->langchain_experimental) (1.0.0)
# Downloading langchain_experimental-0.0.62-py3-none-any.whl (202 kB)
#    ---------------------------------------- 0.0/202.7 kB ? eta -:--:--
#    --- ----------------------------------- 20.5/202.7 kB 640.0 kB/s eta 0:00:01
#    ---------------------- ----------------- 112.6/202.7 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 202.7/202.7 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: langchain_experimental
# Successfully installed langchain_experimental-0.0.62

# %%
import pandas as pd
from langchain_core.prompts import ChatPromptTemplate
from langchain_experimental.tools import PythonAstREPLTool

df = pd.read_csv("./data/titanic.csv")
# titanic.csv 파일에서 데이터를 읽어와 DataFrame으로 저장합니다.
tool = PythonAstREPLTool(locals={"df": df})
# PythonAstREPLTool을 사용하여 로컬 변수 'df'를 포함하는 환경을 생성합니다.
tool.invoke("df")
# 'df' DataFrame에서 'Fare' 열의 평균 값을 계산합니다.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
hello = """
print("Hello, world!")

def add(a, b):
    return a + b

print(add(30, 40))

import pandas as pd

df = pd.read_csv("./data/titanic.csv")
df.head()
"""

# %%
tool = PythonAstREPLTool(locals={"df": df})
# PythonAstREPLTool을 사용하여 로컬 변수 'df'를 포함하는 환경을 생성합니다.
tool.invoke(hello)
# Out:
# Hello, world!
# 70
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 데이터 로드

# %%
import pandas as pd

df = pd.read_csv("data/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Pandas DataFrame Agent

# %%
from langchain.agents.agent_types import AgentType
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain_openai import ChatOpenAI
from langchain.agents.agent_types import AgentType
from langchain.callbacks.base import BaseCallbackHandler


class StreamCallback(BaseCallbackHandler):
    def on_llm_new_token(self, token: str, **kwargs):
        print(token, end="", flush=True)


# # 에이전트 생성
agent = create_pandas_dataframe_agent(
    ChatOpenAI(
        temperature=0,
        model_name="gpt-3.5-turbo-0613",
        streaming=True,
        callbacks=[StreamCallback()],
    ),  # 모델 정의
    df,  # 데이터프레임
    verbose=True,  # 추론과정 출력
    # AgentType.ZERO_SHOT_REACT_DESCRIPTION
    agent_type=AgentType.OPENAI_FUNCTIONS,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 14
#      10         print(token, end="", flush=True)
#      13 # # 에이전트 생성
# ---> 14 agent = create_pandas_dataframe_agent(
#      15     ChatOpenAI(
#      16         temperature=0,
#      17         model_name="gpt-3.5-turbo-0613",
#      18         streaming=True,
#      19         callbacks=[StreamCallback()],
#      20     ),  # 모델 정의
#      21     df,  # 데이터프레임
#      22     verbose=True,  # 추론과정 출력
#      23     # AgentType.ZERO_SHOT_REACT_DESCRIPTION
#      24     agent_type=AgentType.OPENAI_FUNCTIONS,
#      25 )
#
# File c:\Users\UserK\miniforge3\envs\rag\lib\site-packages\langchain_experimental\agents\agent_toolkits\pandas\base.py:248, in create_pandas_dataframe_agent(llm, df, agent_type, callback_manager, prefix, suffix, input_variables, verbose, return_intermediate_steps, max_iterations, max_execution_time, early_stopping_method, agent_executor_kwargs, include_df_in_prompt, number_of_head_rows, extra_tools, engine, allow_dangerous_code, **kwargs)
#     174 """Construct a Pandas agent from an LLM and dataframe(s).
#     175
#     176 Security Notice:
#    (...)
#     245
#     246 """
#     247 if not allow_dangerous_code:
# --> 248     raise ValueError(
#     249         "This agent relies on access to a python repl tool which can execute "
#     250         "arbitrary code. This can be dangerous and requires a specially sandboxed "
#     251         "environment to be safely used. Please read the security notice in the "
#     252         "doc-string of this function. You must opt-in to use this functionality "
#     253         "by setting allow_dangerous_code=True."
#     254         "For general security guidelines, please see: "
#     255         "https://python.langchain.com/v0.2/docs/security/"
#     256     )
#     257 try:
#     258     if engine == "modin":
#
# ValueError: This agent relies on access to a python repl tool which can execute arbitrary code. This can be dangerous and requires a specially sandboxed environment to be safely used. Please read the security notice in the doc-string of this function. You must opt-in to use this functionality by setting allow_dangerous_code=True.For general security guidelines, please see: https://python.langchain.com/v0.2/docs/security/
